# %% [markdown]
# # Test load image file following Image analysis class note

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
path_db = '/Users/connylin/Dropbox/CA/ED _20200119 Brain Station Data Science Diploma/Capstone/data/MWTDB_BS_trim.csv'

# %%
MWTDB = pd.read_csv(path_db)

# %%
path_test_png = MWTDB['png_path'][4000]

# %%
path_test_png
# Out:
# '/Volumes/COBOLT/MWT/20150304C_SM_100s30x10s10s/N2_400mM/20150304_162325/N2_5x3_t96h20C_100s30x10s10s_C0109bb.png'

# %%
im = plt.imread(path_test_png)
print(im.shape)
# Out:
# (1726, 2352)

# %%
im
# Out:
# array([[0.00061036, 0.00061036, 0.0005951 , ..., 0.0005951 , 0.00050355,
#         0.00054932],
#        [0.00061036, 0.00056458, 0.00056458, ..., 0.00056458, 0.00054932,
#         0.00053407],
#        [0.00054932, 0.00054932, 0.0005951 , ..., 0.00054932, 0.00054932,
#         0.0005951 ],
#        ...,
#        [0.00053407, 0.00054932, 0.00050355, ..., 0.00044251, 0.00036622,
#         0.00041199],
#        [0.00048829, 0.00053407, 0.00050355, ..., 0.00036622, 0.00042725,
#         0.00038148],
#        [0.00054932, 0.00053407, 0.00048829, ..., 0.00041199, 0.00050355,
#         0.00041199]], dtype=float32)

# %%
plt.figure(figsize=(10,10))
plt.imshow(im, cmap='gray');
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(im);
plt.show()

# %%
print(f'max = {im.max()}')
print(f'min = {im.min()}')
print(f'mean = {im.mean()}')
# Out:
# max = 0.01521324459463358
# min = 1.5259021893143654e-05
# mean = 0.00481303920969367

# %%
#threshold image
normalized = np.where(im <= 0.00481303920969367, 0, im.max())

plt.figure(figsize=(10,10))
plt.imshow(normalized, cmap='gray');

# %%
# !conda install imageio
import imageio
q

# %%
# processing steps -- 
# trim the image - find boundaries
# Remove background or other distracting artifacts
# Label features using edges and run machine learning models depending on our purposes
# Test and iterate

# split up images
# find wet plates
