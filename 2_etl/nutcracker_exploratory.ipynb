# %%
# EDA nutcracker
# Conny Lin | June 6, 2020

# %%
pCapstone = '/Users/connylin/Dropbox/CA/ED _20200119 Brain Station Data Science Diploma/Capstone/data'

# %%
# import libraries
import os, sys, glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# import local functions
sys.path.insert(1, '/Users/connylin/Dropbox/CA/ED _20200119 Brain Station Data Science Diploma/Capstone/brainstation_capstone/0_lib')
import BrainStationLib as bs

# %%
# load data
data_y = pd.read_csv(os.path.join(pCapstone, 'nutcracker_y.csv'))
data_X = pd.read_csv(os.path.join(pCapstone, 'nutcracker_X.csv'))

# %%
data_X
# Out:
#         Unnamed: 0    time   frame  persistence      area  midline  \
# 0                0  63.499  1575.0         67.5  0.231822   1.2165
# 1                1  63.547  1576.0         67.5  0.229635   1.2372
# 2                2  63.588  1577.0         67.5  0.232551   1.2302
# 3                3  63.628  1578.0         67.5  0.234738   1.2213
# 4                4  63.667  1579.0         67.5  0.231822   1.2273
# ...            ...     ...     ...          ...       ...      ...
# 239933      239933  94.345  2315.0         53.8  0.142155   1.4977
# 239934      239934  94.391  2316.0         53.8  0.141426   1.5051
# 239935      239935  94.433  2317.0         53.8  0.137781   1.5180
# 239936      239936  94.473  2318.0         53.8  0.097686   0.9618
# 239937      239937  94.512  2319.0         53.8  0.135594   1.5325
#
#         morphwidth   width  relwidth  length  ...  kink  curve   speed  \
# 0           0.1887  0.1512     0.685  1.0233  ...   6.7   19.7  0.2918
# 1           0.1868  0.1512     0.685  1.0125  ...  10.3   19.7  0.2349
# 2           0.1911  0.1512     0.685  1.0017  ...  15.9   20.5  0.2589
# 3           0.1920  0.1485     0.673  0.9882  ...  16.6   17.3  0.2740
# 4           0.1889  0.1485     0.673  0.9882  ...  17.5   17.2  0.2680
# ...            ...     ...       ...     ...  ...   ...    ...     ...
# 239933      0.0649  0.2376     1.198  1.4850  ...  28.9   33.4  1.2151
# 239934      0.0663  0.2376     1.198  1.4850  ...  26.0   32.4  0.2333
# 239935      0.0660  0.2376     1.198  1.4850  ...  32.9   34.6  0.8067
# 239936      0.0672  0.1161     0.585  0.9180  ...  43.2   30.6  0.9227
# 239937      0.0621  0.2376     1.198  1.4850  ...  28.9   33.3  1.1694
#
#         angular  bias  dir   vel_x   vel_y  orient    crab
# 0           6.9   1.0  0.0 -0.1199  0.2660   114.8  0.0030
# 1           5.3   1.0  0.0 -0.0788  0.2213   115.1  0.0225
# 2           4.4   1.0  0.0 -0.1105  0.2342   115.3  0.0003
# 3           3.9   1.0  0.0 -0.1133  0.2495   115.4  0.0048
# 4           4.3   1.0  0.0 -0.0835  0.2547   115.6  0.0346
# ...         ...   ...  ...     ...     ...     ...     ...
# 239933     40.5   1.0  0.0 -1.2098 -0.1129    10.6  0.1112
# 239934      1.7   1.0  0.0 -0.2295 -0.0421    10.5  0.0006
# 239935     39.4   1.0  0.0  0.8065  0.0184    10.5  0.1292
# 239936     39.7   0.0  0.0  0.9215  0.0464    14.5  0.1855
# 239937     38.5   0.0  0.0 -1.1672 -0.0721    10.6  0.1448
#
# [239938 rows x 23 columns]

# %%
# explore data
for c in data_X.columns:
    plt.figure()
    plt.hist(data_X[c], bins=100)
    plt.title(c)
    plt.ylabel('count')
    plt.xlabel(c)
    plt.show()

# %% [markdown]
# |column|distribution|notes|
# |---|---|---|
# |time|uniform|expected|
# |frame|drops between 1500-2000||
# |persistence|||
# |area|||
# |midline|||
# |morphwidth|||
# |width|||
# |relwidth|||
# |length|||
# |rellength|||
# |aspect|||
# |relaspect|||
# |kink|||
# |curve|||
# |speed|||
# |angular|||
# |bias|||
# |dir|||
# |vel_x|||
# |vel_y|||
# |orient|||
# |crab|||

# %% [markdown]
# Need to scale data
