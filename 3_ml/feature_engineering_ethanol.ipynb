# %%
# feature selection to predict ethanol
# Conny Lin | May 20, 2020

# %%
# define local variables
# dataoutput dir
dir_save = '/Users/connylin/Dropbox/CA/ED _20200119 Brain Station Data Science Diploma/Capstone/data'

# %%
import os
import pickle
from pathlib import Path
from pathlib import PurePath
import glob
import numpy as np
import pandas as pd

# %%
# load data
pd.read_csv(os.path.join(dir_save, 'drunkposture2_90s_95s_mean.csv'))
# Out:
#       Unnamed: 0                                               path  \
# 0              0  /Volumes/COBOLT/MWT/20100201X_JC_0s0x0s0s_EE01...
# 1              1  /Volumes/COBOLT/MWT/20100201X_JC_0s0x0s0s_EE01...
# 2              2  /Volumes/COBOLT/MWT/20100201X_JC_0s0x0s0s_EE01...
# 3              3  /Volumes/COBOLT/MWT/20110906C_SS_10s30x10s10s_...
# 4              4  /Volumes/COBOLT/MWT/20110906C_SS_10s30x10s10s_...
# ...          ...                                                ...
# 4890        4890  /Volumes/COBOLT/MWT to check/20140819C_SM_100s...
# 4891        4891  /Volumes/COBOLT/MWT to check/20140819C_SM_100s...
# 4892        4892  /Volumes/COBOLT/MWT to check/20140819C_SM_100s...
# 4893        4893  /Volumes/COBOLT/MWT to check/20140819C_SM_100s...
# 4894        4894  /Volumes/COBOLT/MWT to check/20140819C_SM_100s...
#
#            time     number  goodnumber     speed    length     width  \
# 0     92.496992  15.436441    8.436441  0.200195  1.646263  0.400211
# 1     92.514064  22.880000   17.000000  0.240402  1.543665  0.378352
# 2     92.515387  20.000000   16.000000  0.155408  1.394916  0.333621
# 3     92.512595  63.342342   34.666667  0.281322  1.138601  0.296181
# 4     92.532129  63.715517   45.896552  0.255653  1.107579  0.316266
# ...         ...        ...         ...       ...       ...       ...
# 4890  92.488512  24.416000   14.864000  0.139235  0.844069  0.205224
# 4891  92.496992   7.693548    7.000000  0.223061  1.121639  0.210669
# 4892  92.490202  91.412281   54.578947  0.150640  0.776602  0.254953
# 4893  92.515026  63.043478   36.165217  0.187543  0.900554  0.256571
# 4894  92.483984  68.520325   53.056911  0.153269  0.803453  0.189873
#
#         aspect       kink      bias      curve      area   midline  morphwidth
# 0     0.249551  42.700424  0.833886  33.436864  0.327688  1.885453    0.158829
# 1     0.260400  46.947200  0.648528  32.916800  0.302550  1.787706    0.156609
# 2     0.250735  47.729130  0.538539  29.327391  0.256188  1.596133    0.141297
# 3     0.271414  44.956757  0.651532  31.726126  0.174631  1.294836    0.117078
# 4     0.297974  49.812931  0.602483  33.453448  0.189271  1.287250    0.131748
# ...        ...        ...       ...        ...       ...       ...         ...
# 4890  0.261072  43.080000  0.478848  22.268000  0.139424  0.937663    0.126784
# 4891  0.192081  36.200806  0.549532  18.600000  0.230011  1.183268    0.175561
# 4892  0.355237  46.159649  0.478728  31.242982  0.147112  0.900891    0.142496
# 4893  0.315287  47.147826  0.662843  27.988696  0.172028  1.018480    0.147034
# 4894  0.256455  38.596748  0.470114  20.976423  0.131707  0.875350    0.128762
#
# [4895 rows x 15 columns]
