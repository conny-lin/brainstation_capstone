# %%
# process matlab produced csv and convert pickle back to csv
# Conny Lin | June 5, 2020

# %%
# load library
import os
import sys
import pickle
import time
import numpy as np
import pandas as pd
import subprocess
import glob

# import functions
dir_function_collection = [
'/Users/connylin/Dropbox/Code/language/python_lib/localpackage/mwt',
'/Users/connylin/Dropbox/CA/ED _20200119 Brain Station Data Science Diploma/Capstone/brainstation_capstone/0_lib'
]
for p in dir_function_collection:
    sys.path.insert(1, p)

import BrainStationLib as bs

# %%
# define global varialbes/paths
pDropbox_home = '/Users/connylin/Dropbox/MWT/db'
pCapstone = '/Users/connylin/Dropbox/CA/ED _20200119 Brain Station Data Science Diploma/Capstone/data'

# %%
# load MWTDB for dropbox
MWTDB = pd.read_csv(pDropbox_home+'/MWTDB.csv', index_col=False)
MWTDB
# Out:
#       mwtid                                            mwtpath  \
# 0         0  /Users/connylin/Dropbox/MWT/db/MWT/20141216B_S...
# 1         1  /Users/connylin/Dropbox/MWT/db/MWT/20141216B_S...
# 2         2  /Users/connylin/Dropbox/MWT/db/MWT/20141216B_S...
# 3         3  /Users/connylin/Dropbox/MWT/db/MWT/20141216B_S...
# 4         4  /Users/connylin/Dropbox/MWT/db/MWT/20141216B_S...
# ...     ...                                                ...
# 7289   7289  /Users/connylin/Dropbox/MWT/db/MWT to check/20...
# 7290   7290  /Users/connylin/Dropbox/MWT/db/MWT to check/20...
# 7291   7291  /Users/connylin/Dropbox/MWT/db/MWT to check/20...
# 7292   7292  /Users/connylin/Dropbox/MWT/db/MWT to check/20...
# 7293   7293  /Users/connylin/Dropbox/MWT/db/MWT to check/20...
#
#                              expname    groupname        platename
# 0     20141216B_SI_100s30x10s10s_MT1        RB982  20141216_175807
# 1     20141216B_SI_100s30x10s10s_MT1        RB982  20141216_173721
# 2     20141216B_SI_100s30x10s10s_MT1        RB982  20141216_182015
# 3     20141216B_SI_100s30x10s10s_MT1        RB982  20141216_171635
# 4     20141216B_SI_100s30x10s10s_MT1  RB982_400mM  20141216_180658
# ...                              ...          ...              ...
# 7289      20140819C_SM_100s30x10s10s      ungroup  20140819_172227
# 7290      20140819C_SM_100s30x10s10s      ungroup  20140819_191228
# 7291      20140819C_SM_100s30x10s10s      ungroup  20140819_182649
# 7292      20140819C_SM_100s30x10s10s      ungroup  20140819_173055
# 7293      20140819C_SM_100s30x10s10s      ungroup  20140819_192732
#
# [7294 rows x 5 columns]

# %%
MWTDBTNT = pickle.load(open(os.path.join(pCapstone,'MWTDB_trinity_N2400mM.pickle'),'rb'))

# %%
istart = 300
for iMWTDB in MWTDB.index.values[istart:]:
    # get path
    pmwt = MWTDB.loc[iMWTDB, 'mwtpath']
    print(f'{iMWTDB}: {pmwt}')

    # check if has trinity_cleaned.csv, 
    ptrinity_cleaned = os.path.join(pmwt,'trinity_cleaned.csv')
    ptrinity_pickle = os.path.join(pmwt,'trinity_all_worms.pickle')
    ptrinity_idin = os.path.join(pmwt,'trinity_idin.csv')
    ptrinity_meta = os.path.join(pmwt,'trinity_meta.csv')
    ptrinity_csv = os.path.join(pmwt,'trinity.csv')
    
    # instantiate dataframe
    df = pd.DataFrame({'failed':[0]})

    # if no, trinity_cleaned.csv
    if not os.path.isfile(ptrinity_cleaned):
        print('\tno trinity_cleaned')
        # check if has trinity_all_worms.pickle
        # if yes
        if os.path.isfile(ptrinity_pickle):
            print(f'\tfound pickle file')
            # load data
            df = pickle.load(open(ptrinity_pickle,'rb'))
            # get MWTDB id
            plateid = MWTDB.loc[iMWTDB, 'mwtid']
            # add mwtid column
            df.insert(0, 'mwtid', np.tile(plateid, df.shape[0]))
            # drop mwtid_trdb column
            df.drop(columns=['mwtid_trdb'], inplace=True)
            # save as trinity_cleaned.csv
            df.to_csv(ptrinity_cleaned, index=False)
            print(f'\twrite trinity_cleaned.csv')
            
        # if no, 
        elif not os.path.isfile(ptrinity_pickle):
            print('\tno pickle')
            # check if have trinity_idin.csv
            # if no, 
            if not os.path.isfile(ptrinity_idin):
                print(f'\tno trinity_idin.csv')
                # check if has both trinity_meta.csv and trinity.csv
                # if yes, 
                if os.path.isfile(ptrinity_meta) & \
                    os.path.isfile(ptrinity_csv):
                    print('\thas both meta and csv')
                    assert False, 'code this option'
                    # load trinity_meta.csv
                    # create worm id column by rows
                    # load trinity.csv
                    # concat with trinity.csv, 
                    # remove columns
                # if no, leave the plate be
                else:
                    print(f'\tno both (meta, csv) or pickle. Skip')
                    continue
                    assert False, 'code this option'
                    
            # if yes,
            elif os.path.isfile(ptrinity_idin):
                print(f'\tfound trinity_idin.csv')
                # load trinity_idin.csv
                df = pd.read_csv(ptrinity_idin)
                TD = bs.TrinityData(ptrinity_idin)
                df = TD.loaddata()
            else:
                print(f'\tsome weird unforseen scenario')
                assert False, 'code this option'
            
            # [now should have the same dataframe]
            # check df is right size
            if df.shape[1]==14:
                print(f'\tgathered right dataframe.csv')
                # clean out nan values
                df.dropna(axis=0, inplace=True)
                # add plate id
                plateid = MWTDB.loc[iMWTDB, 'mwtid']
                df.insert(0, 'mwtid', np.tile(plateid, df.shape[0]))
                # add etoh id
                etoh = 0
                if '00mM' in MWTDB.loc[iMWTDB, 'groupname']:
                    etoh = 1
                df.insert(1, 'etoh', np.tile(etoh, df.shape[0]))
                # save as trinity_cleaned.csv 
                print(f'\twrite trinity_cleaned.csv')
                df.to_csv(ptrinity_cleaned, index=False)

        else:
            print(f'\tsome weird unforseen scenario')
            assert False, 'code this option'
    else:
        print(f'\talready has trinity_cleaned.csv')

    # final check to see if trinity_cleaned exist
    if os.path.isfile(ptrinity_cleaned):
        print(f'\ttrinity_cleaned.csv present, delete redundant files')
        # if so, delete trinity_meta.csv, trinity.csv, and pickle
        if os.path.isfile(ptrinity_idin):
            os.remove(ptrinity_idin)
            print('\tdeleted trinity_idin.csv')
        if os.path.isfile(ptrinity_pickle):
            os.remove(ptrinity_pickle)
            print('\tdeleted trinity pickle file')
        if os.path.isfile(ptrinity_meta):
            os.remove(ptrinity_meta)
            print('\tdeleted trinity meta file')
        if os.path.isfile(ptrinity_csv):
            os.remove(ptrinity_csv)
            print('\tdeleted trinity.csv file')
# Out:
# 300: /Users/connylin/Dropbox/MWT/db/MWT/20130926B_SJ_100s30x10s10s_Neuroligin/VC228_400mM/20130926_205708
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
#
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 424: /Users/connylin/Dropbox/MWT/db/MWT/20120830C_DC_100s31x10s10s_10sISIRec5min/N2/20120830_203012
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 425: /Users/connylin/Dropbox/MWT/db/MWT/20120830C_DC_100s31x10s10s_10sISIRec5min/N2/20120830_205515
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 426: /Users/connylin/Dropbox/MWT/db/MWT/20120830C_DC_100s31x10s10s_10sISIRec5min/N2/20120830_200443
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 427: /Users/connylin/Dropbox/MWT/db/MWT/20120830C_DC_100s31x10s10s_10sISIRec5min/N2/20120830_211957
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 428: /Users/connylin/Dropbox/MWT/db/MWT/20120408C_DA_100s30x45s10s/NM1968/20120408_200620
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 429: /Users/connylin/Dropbox/MWT/db/MWT/20120408C_DA_100s30x45s10s/NM1968/20120408_211723
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 430: /Users/connylin/Dropbox/MWT/db/MWT/20120408C_DA_100s30x45s10s/NM1968/20120408_224126
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 431: /Users/connylin/Dropbox/MWT/db/MWT/20120408C_DA_100s30x45s10s/NM1630/20120408_193501
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 432: /Users/connylin/Dropbox/MWT/db/MWT/20140502B_AH_3600s0x0s0s_60mhistonemutants/MT14390_400mM/20140502_170029
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 433: /Users/connylin/Dropbox/MWT/db/MWT/20140502B_AH_3600s0x0s0s_60mhistonemutants/MT14390_400mM/20140502_145406
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 434: /Users/connylin/Dropbox/MWT/db/MWT/20140502B_AH_3600s0x0s0s_60mhistonemutants/MT14390_400mM/20140502_125135
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 435: /Users/connylin/Dropbox/MWT/db/MWT/20140502B_AH_3600s0x0s0s_60mhistonemutants/MT14390/20140502_135205
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 436: /Users/connylin/Dropbox/MWT/db/MWT/20140502B_AH_3600s0x0s0s_60mhistonemutants/MT14390/20140502_155826
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 437: /Users/connylin/Dropbox/MWT/db/MWT/20140502B_AH_3600s0x0s0s_60mhistonemutants/MT14390/20140502_115104
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 438: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/N2/20120330_132929
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 439: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/N2/20120330_130425
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 440: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/N2/20120330_124747
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 441: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/N2/20120330_123000
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 442: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/N2/20120330_121140
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 443: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/DA465/20120330_122230
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 444: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/DA465/20120330_124734
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 445: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/DA465/20120330_125646
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 446: /Users/connylin/Dropbox/MWT/db/MWT/20120330C_CL_100s30x10s10s/DA465/20120330_123946
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 447: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/N2_5d/20150126_110553
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 448: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/N2_5d/20150126_114612
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 449: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/N2_5d/20150126_120710
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 450: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/N2_5d/20150126_112721
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 451: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/KJ300_400mM_5d/20150126_132446
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 452: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/KJ300_400mM_5d/20150126_134557
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 453: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/KJ300_400mM_5d/20150126_121708
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 454: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/KJ300_400mM_5d/20150126_124007
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 455: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/N2_400mM_5d/20150126_125051
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 456: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/N2_400mM_5d/20150126_135337
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 457: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/N2_400mM_5d/20150126_122548
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 458: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/N2_400mM_5d/20150126_133813
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 459: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/KJ300_5d/20150126_111332
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 460: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/KJ300_5d/20150126_115727
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 461: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/KJ300_5d/20150126_105707
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 462: /Users/connylin/Dropbox/MWT/db/MWT/20150126B_AT_100s30x10s10s/KJ300_5d/20150126_113649
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 463: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/KP4/20140806_171830
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 464: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/KP4/20140806_143142
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 465: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/KP4/20140806_162051
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 466: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/KP4/20140806_152230
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 467: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/N2_400mM/20140806_142335
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 468: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/N2_400mM/20140806_160437
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 469: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/N2_400mM/20140806_170518
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 470: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/N2_400mM/20140806_161242
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 471: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/VM3109_400mM/20140806_150059
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 472: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/VM3109_400mM/20140806_154658
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 473: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/KP4_400mM/20140806_144057
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 474: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/KP4_400mM/20140806_164011
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 475: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/KP4_400mM/20140806_153026
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 476: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/KP4_400mM/20140806_172631
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 477: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/N2/20140806_141451
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 478: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/N2/20140806_155446
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 479: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/N2/20140806_150931
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 480: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/N2/20140806_165709
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 481: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/VM3109/20140806_153907
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 482: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/VM3109/20140806_144903
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 483: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/VM3109/20140806_175401
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 484: /Users/connylin/Dropbox/MWT/db/MWT/20140806B_SJ_100s30x10s10s_glr1_10s/VM3109/20140806_164820
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 485: /Users/connylin/Dropbox/MWT/db/MWT/20130430B_CL_100s30x15s10s_15sISI/N2_400mM/20130430_170208
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 486: /Users/connylin/Dropbox/MWT/db/MWT/20130430B_CL_100s30x15s10s_15sISI/N2_400mM/20130430_163754
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 487: /Users/connylin/Dropbox/MWT/db/MWT/20130430B_CL_100s30x15s10s_15sISI/N2_400mM/20130430_155055
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 488: /Users/connylin/Dropbox/MWT/db/MWT/20130430B_CL_100s30x15s10s_15sISI/N2_400mM/20130430_175135
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 489: /Users/connylin/Dropbox/MWT/db/MWT/20130430B_CL_100s30x15s10s_15sISI/N2/20130430_171800
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 490: /Users/connylin/Dropbox/MWT/db/MWT/20130430B_CL_100s30x15s10s_15sISI/N2/20130430_153647
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 491: /Users/connylin/Dropbox/MWT/db/MWT/20130430B_CL_100s30x15s10s_15sISI/N2/20130430_161811
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 492: /Users/connylin/Dropbox/MWT/db/MWT/20130430B_CL_100s30x15s10s_15sISI/N2/20130430_165105
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 493: /Users/connylin/Dropbox/MWT/db/MWT/20121007A_JX_900s0x0s0s_15min/N2_400mM/20121007_152356
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 494: /Users/connylin/Dropbox/MWT/db/MWT/20121007A_JX_900s0x0s0s_15min/N2_400mM/20121007_155557
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 495: /Users/connylin/Dropbox/MWT/db/MWT/20121007A_JX_900s0x0s0s_15min/N2_400mM/20121007_162755
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 496: /Users/connylin/Dropbox/MWT/db/MWT/20121007A_JX_900s0x0s0s_15min/N2_400mM/20121007_165905
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 497: /Users/connylin/Dropbox/MWT/db/MWT/20121007A_JX_900s0x0s0s_15min/N2/20121007_161202
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 498: /Users/connylin/Dropbox/MWT/db/MWT/20121007A_JX_900s0x0s0s_15min/N2/20121007_164325
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 499: /Users/connylin/Dropbox/MWT/db/MWT/20121007A_JX_900s0x0s0s_15min/N2/20121007_153929
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 500: /Users/connylin/Dropbox/MWT/db/MWT/20121007A_JX_900s0x0s0s_15min/N2/20121007_150807
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 501: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime90min/20120112_214300
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 502: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime90min/20120112_215835
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 503: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime90min/20120112_193441
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 504: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime90min/20120112_190942
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 505: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime60min/20120112_205047
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 506: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime60min/20120112_222223
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 507: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime60min/20120112_210802
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 508: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime30min/20120112_224135
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 509: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime30min/20120112_231940
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 510: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime30min/20120112_233900
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 511: /Users/connylin/Dropbox/MWT/db/MWT/20120112C_FP_100s30x10s10s_ExpTime/N2_400mM_ExpTime30min/20120112_234719
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 512: /Users/connylin/Dropbox/MWT/db/MWT/20111103C_SS_100s30x60s10s/N2_ER5d_a/20111103_132309
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 513: /Users/connylin/Dropbox/MWT/db/MWT/20111103C_SS_100s30x60s10s/N2_ER5d_a/20111103_124932
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 514: /Users/connylin/Dropbox/MWT/db/MWT/20111103C_SS_100s30x60s10s/N2_ER5d_a/20111103_114250
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 515: /Users/connylin/Dropbox/MWT/db/MWT/20111103C_SS_100s30x60s10s/N2_ER5d_a/20111103_121532
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 516: /Users/connylin/Dropbox/MWT/db/MWT/20111103C_SS_100s30x60s10s/N2_ER5d_b/20111103_150123
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 517: /Users/connylin/Dropbox/MWT/db/MWT/20111103C_SS_100s30x60s10s/N2_ER5d_b/20111103_135625
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 518: /Users/connylin/Dropbox/MWT/db/MWT/20111103C_SS_100s30x60s10s/N2_ER5d_b/20111103_142858
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 519: /Users/connylin/Dropbox/MWT/db/MWT/20121209C_DC_100s31x60s10s_60sISIRec5min/N2_400mM/20121209_172047
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 520: /Users/connylin/Dropbox/MWT/db/MWT/20121209C_DC_100s31x60s10s_60sISIRec5min/N2_400mM/20121209_183756
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 521: /Users/connylin/Dropbox/MWT/db/MWT/20121209C_DC_100s31x60s10s_60sISIRec5min/N2_400mM/20121209_195442
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 522: /Users/connylin/Dropbox/MWT/db/MWT/20121209C_DC_100s31x60s10s_60sISIRec5min/N2_400mM/20121209_211113
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 523: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK1165_400mM/20190331_130725
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 524: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK1165_400mM/20190331_122756
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 525: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK1165_400mM/20190331_120210
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 526: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK1165_400mM/20190331_125035
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 527: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK1165_400mM/20190331_121929
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 528: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK1165_400mM/20190331_105957
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 529: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796_400mM/20190331_123609
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 530: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796_400mM/20190331_113337
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 531: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796_400mM/20190331_125929
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 532: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796_400mM/20190331_103858
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 533: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796_400mM/20190331_104846
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 534: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796_400mM/20190331_112007
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 535: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/NM1968/20190331_115000
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 536: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/NM1968/20190331_105952
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 537: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/NM1968/20190331_112321
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 538: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/NM1968/20190331_112931
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 539: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/NM1968/20190331_121106
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 540: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/NM1968/20190331_121935
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 541: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/N2_400mM/20190331_130234
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 542: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/N2_400mM/20190331_122801
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 543: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/N2_400mM/20190331_115252
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 544: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/N2_400mM/20190331_121710
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 545: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/N2_400mM/20190331_120848
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 546: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/N2_400mM/20190331_130152
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 547: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796/20190331_122538
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 548: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796/20190331_112327
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 549: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796/20190331_124220
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 550: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796/20190331_105451
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 551: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796/20190331_104841
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 552: /Users/connylin/Dropbox/MWT/db/MWT/20190331X_XX_100s30x10s10s_slo1/HKK796/20190331_113941
# 	already has trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# ...
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2307: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/KG524_400mM/20150107_161423
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2308: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/KG524_400mM/20150107_155337
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2309: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/KG524_400mM/20150107_160606
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2310: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/KG524/20150107_141415
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2311: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/KG524/20150107_143321
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2312: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/KG524/20150107_142157
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2313: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/KG524/20150107_144240
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2314: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/N2_400mM/20150107_150412
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2315: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/N2_400mM/20150107_152159
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2316: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/N2_400mM/20150107_154122
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2317: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/N2_400mM/20150107_153205
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2318: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/N2/20150107_132249
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2319: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/N2/20150107_130651
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2320: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/N2/20150107_140226
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2321: /Users/connylin/Dropbox/MWT/db/MWT/20150107A_SM_100s30x10s10s/N2/20150107_133244
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2322: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/NM1968/20111115_093553
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 2323: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/NM1968/20111115_093424
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 2324: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/NM1968/20111115_093724
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 2325: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/NM1630/20111115_090028
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 2326: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/NM1630/20111115_090212
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 2327: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/NM1630/20111115_085903
# 	no trinity_cleaned
# 	no pickle
# 	no trinity_idin.csv
# 	no both (meta, csv) or pickle. Skip
# 2328: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/N2/20111115_100818
# 	no trinity_cleaned
# 	found pickle file
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 	deleted trinity pickle file
# 	deleted trinity meta file
# 	deleted trinity.csv file
# 2329: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/N2/20111115_100946
# 	no trinity_cleaned
# 	found pickle file
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 	deleted trinity pickle file
# 	deleted trinity meta file
# 	deleted trinity.csv file
# 2330: /Users/connylin/Dropbox/MWT/db/MWT/20111115B_DA_100s30x60s10s/N2/20111115_101120
# 	no trinity_cleaned
# 	found pickle file
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 	deleted trinity pickle file
# 	deleted trinity meta file
# 	deleted trinity.csv file
# 2331: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/RB1012_400mM/20150901_195529
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2332: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/RB1012_400mM/20150901_201740
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2333: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/RB1012_400mM/20150901_201024
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2334: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/RB1012_400mM/20150901_200305
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2335: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/JT47_400mM/20150901_194031
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2336: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/JT47_400mM/20150901_193317
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2337: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/JT47_400mM/20150901_194810
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2338: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/JT47_400mM/20150901_192556
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2339: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/N2_400mM/20150901_185545
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2340: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/N2_400mM/20150901_191834
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2341: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/N2_400mM/20150901_191047
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2342: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/N2_400mM/20150901_190319
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2343: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/N2/20150901_172040
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2344: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/N2/20150901_174405
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2345: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/N2/20150901_172800
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2346: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/N2/20150901_173623
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2347: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/RB1012/20150901_182402
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2348: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/RB1012/20150901_183128
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2349: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/RB1012/20150901_183851
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2350: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/RB1012/20150901_184649
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2351: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/JT47/20150901_181543
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2352: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/JT47/20150901_175215
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2353: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/JT47/20150901_180014
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2354: /Users/connylin/Dropbox/MWT/db/MWT/20150901C_ST_100s30x10s10s/JT47/20150901_180807
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2355: /Users/connylin/Dropbox/MWT/db/MWT/20120516C_BM_100s30x10s10s/N2_400mM/20120516_163957
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2356: /Users/connylin/Dropbox/MWT/db/MWT/20120516C_BM_100s30x10s10s/N2_400mM/20120516_165616
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# 	trinity_cleaned.csv present, delete redundant files
# 	deleted trinity_idin.csv
# 2357: /Users/connylin/Dropbox/MWT/db/MWT/20120516C_BM_100s30x10s10s/N2_400mM/20120516_171216
# 	no trinity_cleaned
# 	no pickle
# 	found trinity_idin.csv
# 	gathered right dataframe.csv
# 	write trinity_cleaned.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e4bed08e9414> in <module>
#      85                 # save as trinity_cleaned.csv
#      86                 print(f'\twrite trinity_cleaned.csv')
# ---> 87                 df.to_csv(ptrinity_cleaned, index=False)
#      88
#      89         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save(self)
#     321                 break
#     322
# --> 323             self._save_chunk(start_i, end_i)
#     324
#     325     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     336                 decimal=self.decimal,
#     337                 date_format=self.date_format,
# --> 338                 quoting=self.quoting,
#     339             )
#     340
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in to_native_types(self, slicer, na_rep, float_format, decimal, quoting, **kwargs)
#    2065
#    2066             if not quoting:
# -> 2067                 values = values.astype(str)
#    2068             else:
#    2069                 values = np.array(values, dtype="object")
#
# KeyboardInterrupt:

# %%
# stopped at 2356

# %%
assert False, 'stop'
